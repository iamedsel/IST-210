# %% [markdown]
# <a href="https://colab.research.google.com/github/iamedsel/IST-210/blob/master/Group_Assignment_1_Template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # General Online Retail(Similar to amazon)

# %% [markdown]
# ### what is your idea?

# %% [markdown]
# We are doing an Amazon-esque online retail store. We will be retailing general merchandise in any category related to Penn State and the classroom and the product will be shipped directly to the customer.

# %% [markdown]
# ### what makes it unique?

# %% [markdown]
# Our company is limited to Penn State students and provides classroom supplies to the students.

# %% [markdown]
# ### is this a brand-new product or business, or are you borrowing from another business?

# %% [markdown]
# We are borrowing the idea from Amazon. However, we incorporated our own twist into it, in which we will only be providing service to Penn State students.

# %% [markdown]
# ### describe a typical business interaction or a day at your business.

# %% [markdown]
# A student can login using their PSU ID and password. Then, they can find whatever they are looking for, and add it to the cart. When they are finished, they can check out, and put in a valid address for the goos

# %% [markdown]
# ### list your 5 entities/tables and for each, provide details about what data will be stored in the entities/tables.

# %% [markdown]
# 1. Customer
#
# -- Included in this entity will be First Name, Last Name, PSU ID, and address.
#
# 2. Product
#
# -- Will include product ID, price,and description.
#
# 3. Shipping
#
# -- Includes shipping price, location, and postal service.
#
# 4. Support
#
# -- Includes order number, live chat, a support hotline, and tracking numbers.
#
# 5. Access
#
# -- Will contain username, password, and secured payment information.

# %% [markdown]
# Draw IO Entity Relationship Diagram
#
# - save your ER Diagram in Draw.io as PNG and upload it to GitHub
#
# ![Screen Shot 2020-09-18 at 11.34.28 AM.png](data:image/png;base64,...)

# %% [markdown]
# ### provide a goal for your project

# %% [markdown]
# Our goal is to provide limited and secure access for Penn State students to buy classroom supplies in an online environmet. These products will be shipped directly to the student quickly and efficiently.
