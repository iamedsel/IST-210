# %% [markdown]
# <a href="https://colab.research.google.com/github/iamedsel/IST-210/blob/master/New_Python_3_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Do you like using Jupyter Notebooks?

# %% [markdown]
# I would say that I do not particularly like using Jupyter Notebooks yet. Once I get a grasp of how they fully work, I think I may really like Jupyter Notebooks!

# %% [markdown]
# ### What do you want to learn more about in Jupyter Notebooks?

# %% [markdown]
# Jupyter Notebooks offer a wide variety of virtual notebook customizations. There are text and code options to add to your notebook. I want to learn more about what you can do with the code once in Jupyter Notebooks.

# %% [markdown]
# ![Astro3.png](data:image/png;base64,...)
